# %%
import pandas as pd
from kafka import KafkaConsumer
from time import sleep
from json import dumps, loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['52.47.182.5:9092'],
    value_deserializer= lambda x: loads(x.decode('utf-8')))

# %%
s3 = S3FileSystem(profile='default')

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-project-manuelgomez/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[13], line 2
#       1 for count, i in enumerate(consumer):
# ----> 2     with s3.open("s3://kafka-project-manuelgomez/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\spec.py:2178, in AbstractBufferedFile.close(self)
#    2176 else:
#    2177     if not self.forced:
# -> 2178         self.flush(force=True)
#    2180     if self.fs is not None:
#    2181         self.fs.invalidate_cache(self.path)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\spec.py:2041, in AbstractBufferedFile.flush(self, force)
#    2038         self.closed = True
#    2039         raise
# -> 2041 if self._upload_chunk(final=force) is not False:
#    2042     self.offset += self.buffer.seek(0, 2)
#    2043     self.buffer = io.BytesIO()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:2430, in S3File._upload_chunk(self, final)
#    2427             upload_part(self.buffer.read(self.part_max))
#    2429 if self.autocommit and final:
# -> 2430     self.commit()
#    2431 else:
#    2432     # update 'upload offset'
#    2433     self.offset += self.buffer.tell()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:2455, in S3File.commit(self)
#    2453     if self.acl:
#    2454         kw["ACL"] = self.acl
# -> 2455     write_result = self._call_s3("put_object", **kw)
#    2456 else:
#    2457     raise RuntimeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:2290, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2289 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2290     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:371, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     369 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     370 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 371 return await _error_wrapper(
#     372     method, kwargs=additional_kwargs, retries=self.retries
#     373 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:146, in _error_wrapper(func, args, kwargs, retries)
#     144         err = e
#     145 err = translate_boto_error(err)
# --> 146 raise err
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:114, in _error_wrapper(func, args, kwargs, retries)
#     112 for i in range(retries):
#     113     try:
# --> 114         return await func(*args, **kwargs)
#     115     except S3_RETRYABLE_ERRORS as e:
#     116         err = e
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\client.py:394, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     390     maybe_compress_request(
#     391         self.meta.config, request_dict, operation_model
#     392     )
#     393     apply_request_checksum(request_dict)
# --> 394     http, parsed_response = await self._make_request(
#     395         operation_model, request_dict, request_context
#     396     )
#     398 await self.meta.events.emit(
#     399     f'after-call.{service_id}.{operation_name}',
#     400     http_response=http,
#    (...)
#     403     context=request_context,
#     404 )
#     406 if http.status_code >= 300:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\client.py:420, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     416 async def _make_request(
#     417     self, operation_model, request_dict, request_context
#     418 ):
#     419     try:
# --> 420         return await self._endpoint.make_request(
#     421             operation_model, request_dict
#     422         )
#     423     except Exception as e:
#     424         await self.meta.events.emit(
#     425             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#     426             exception=e,
#     427             context=request_context,
#     428         )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\endpoint.py:96, in AioEndpoint._send_request(self, request_dict, operation_model)
#      94 context = request_dict['context']
#      95 self._update_retries_context(context, attempts)
# ---> 96 request = await self.create_request(request_dict, operation_model)
#      97 success_response, exception = await self._get_response(
#      98     request, operation_model, context
#      99 )
#     100 while await self._needs_retry(
#     101     attempts,
#     102     operation_model,
#    (...)
#     105     exception,
#     106 ):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\endpoint.py:84, in AioEndpoint.create_request(self, params, operation_model)
#      82     service_id = operation_model.service_model.service_id.hyphenize()
#      83     event_name = f'request-created.{service_id}.{operation_model.name}'
# ---> 84     await self._event_emitter.emit(
#      85         event_name,
#      86         request=request,
#      87         operation_name=operation_model.name,
#      88     )
#      89 prepared_request = self.prepare_request(request)
#      90 return prepared_request
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\hooks.py:68, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      65 logger.debug('Event %s: calling handler %s', event_name, handler)
#      67 # Await the handler if its a coroutine.
# ---> 68 response = await resolve_awaitable(handler(**kwargs))
#      69 responses.append((handler, response))
#      70 if stop_on_response and response is not None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\signers.py:90, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      87     else:
#      88         raise e
# ---> 90 auth.add_auth(request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\botocore\auth.py:424, in SigV4Auth.add_auth(self, request)
#     422 def add_auth(self, request):
#     423     if self.credentials is None:
# --> 424         raise NoCredentialsError()
#     425     datetime_now = datetime.datetime.utcnow()
#     426     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
